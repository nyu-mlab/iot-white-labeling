# %%
api_key = "AIzaSyCWI_hG6QwceCGyorH-zqfQr10cxMJbiLQ"

# 2 requests in one minute
# 50 requests in a day

# %%
pip install google-generativeai

# %%
api_key = "Replace yours"
text = "Easy to Sign Up Simple EOJO app sign up with your Gmail or Apple ID, sparing you from answering numerous and tedious questions. Easy Installation Simply remove the plastic cover, adhere it to the window surface, and you're ready to go. Instant Alerts on Your Smartphone Whenever motion or person is detected. An EOJO Basic or Plus subscription plan is required for this feature. Upon adding your first camera to the EOJO App, you automatically receive a 30-days free trial. 24/7 Recording Continuous video recording is carried out on the included SD card. You can access and download the video footage from the \"Playback\" section within the EOJO app. Features Straightforward yet powerful and practical features. Local Storage A 64GB SD card is provided at no additional cost, eliminating the need to purchase this accessory separately. Peel Remove the plastic film from the adhesive prior to installation. Mount Attach the camera to the window surface using the adhesive provided. Subscription Plan Receive immediate alerts on your smartphone through the EOJO Basic or Plus plan whenever motion or a person is detected. Opt for the yearly plan to enjoy additional savings. Product information Product Dimensions 3.74 x 2.68 x 2.95 inches Item Weight 4.6 ounces ASIN B0CLBLCD5K Item model number CK-003 Customer Reviews 4.1 19 ratings 4.1 out of 5 stars Best Sellers Rank #218 in Bullet Surveillance Cameras Date First Available October 18, 2023 Manufacturer EOJO Country of Origin China Warranty & Support Product Warranty: For warranty information about this product, please click here Feedback Would you like to tell us about a lower price?"

import google.generativeai as genai
import os

genai.configure(api_key=api_key)

model = genai.GenerativeModel('gemini-pro')
response = model.generate_content('Give me the app name from this text: ' + text)

print(response.parts)
# Out:
# []

# %%
totalTokens = model.count_tokens(text)

totalTokens
# Out:
# total_tokens: 353

# %%
print(type(totalTokens))
# Out:
# <class 'google.ai.generativelanguage_v1beta.types.generative_service.CountTokensResponse'>

# %%
import pandas as pd

cameras_data = "/content/amazon_smart_cameras_products_dataset - amazon_smart_cameras_products_dataset (1).csv"

df = pd.read_csv(cameras_data)

print(df.head())
# Out:
#            id                                           name       brand  \
# 0  B0CLBLCD5K              EOJO Indoor Cameras Home Security        EOJO
# 1  B0C67X3J5F     Arlo Essential Outdoor Security Generation        Arlo
# 2  B08GHX9G5L                Kasa Smart Home Security Camera  Kasa Smart
# 3  B07X6C9RMF                          Blink Mini White 1Cam       Blink
# 4  B0BK2KCC3C  UPULTRA Security Wireless Panoramic Detection     UPULTRA
#
#                                    short_description  \
# 0  MINI SECURITY CAMERA WITH PHONE APP- See every...
# 1  2K Video: Zoom in to clearly see important det...
# 2  Live Steam from Anywhere with Pan/Tilt: Sharp ...
# 3  Monitor the inside of your home day and night ...
# 4  Wireless & Easy Installation: This security ca...
#
#                                     long_description  \
# 0   Easy to Sign Up\nSimple EOJO app sign up with...
# 1  Arlos mission is to bring you peace of mind by...
# ...

# %%
long_descriptions = []

long_descriptions = df['long_description']

long_descriptions_first_half = long_descriptions[0:90]

long_descriptions_first_quarter = long_descriptions[45:91]

long_descriptions_first_quarter
# Out:
# 45    Rebluum were established in 2022,mainly engage...
# 46     1080P Smart AI Wireless Security Camera with ...
# 47     Popular Features\nEasy Setup\nEasily install ...
# 48    Born in the Netherlands, Arenti is founded by ...
# 49      Product information\nPackage Dimensions 5.87...
# 50      Product information\nPackage Dimensions 7.17...
# 51     The baby monitor have senior encryption video...
# 52     Waterproof Light Bulb Security Camera Outdoor...
# 53      Product information\nPackage Dimensions 5.04...
# 54    Top Rating Products\nVisit the Store Play Vide...
# 55    JOOAN were established in 2008, which is a cut...
# 56     Play Video Product information\nProduct Dimen...
# 57    Arlos mission is to bring you peace of mind by...
# 58    New Products\nHot Products\nVIKYLIN was founde...
# 59    Founded in the City of Industry, Shenzhen, Chi...
# 60     Play Video\n1 Indoor Camera 2 Human Detection...
# 61    E1 Pro\n4MP WiFi Indoor Camera, 2.4/5 GHz WiFi...
# ...

# %%
sum = 0

for ld in long_descriptions_first_quarter:
  totalTokens = model.count_tokens(ld)
  sum += totalTokens.total_tokens

print("totalTokens: ", sum)
# Out:
# totalTokens:  27807

# %%
api_key = "AIzaSyCWI_hG6QwceCGyorH-zqfQr10cxMJbiLQ"

import google.generativeai as genai
import os

genai.configure(api_key=api_key)

long_descriptions_first_quarter_list = long_descriptions_first_quarter.tolist()
long_descriptions_string = ''.join(long_descriptions_first_quarter_list)

model = genai.GenerativeModel('gemini-pro')
response = model.generate_content('Give me the app names in new lines for each of the strings in the string array. If you cannot find an app name, say "app name not found" instead: ' + long_descriptions_string)

print(response.parts)

output_text = response.parts
# Out:
# [text: "1. Rebluum were established in 2022,mainly engaged in offering easy-to-use & affordable Wireless Systems for all clients.\n2. All the surveillance cameras are equipped with the latest features to bring you the best experience.The design of our camera is prefect for almost installation environment. With operation video,you can do it all by yourself.\n3. Explore More from Rebluum\n4. Wireless Doorbell Camera Wireless Doorbell Camera Wireless Security Camera Light Bulb Security Camera\n5. Add to Cart\n6. Add to Cart\n7. Add to Cart\n8. Add to Cart\n9. 1 Non-Stop Solar Power\n10. 2 Two Storage Methods\n11. 3 Smart Detection\n12. 4 Ultra Clear Night Vision\n13. 5 4X Digital Zoom\nCamera size: 7 x 5 x 8 inches\nItem Weight: 12 ounces\nASIN: B0BPY6SRRG\nItem model number: P2Q-4MP2-4G\nCustomer Reviews: 4.5\n601 ratings\n4.5 out of 5 stars\nBest Sellers Rank: #98 in Dome Surveillance Cameras\nDate First Available: February 14, 2023\nManufacturer: Rebluum\nCountry of Origin: China\nWa
# ...

# %%
# [text: "* Arlo\n* Blink\n* EZVIZ\n* Gatijan\n* HowKow\n* JAIOT\n* Kami\n* Kasa\n* LaView\n* Litokam\n* Noorio\n* Owltron\n* PANOOB\n* Reolink\n* Tapo\n* TP-Link\n* Vision Well\n* WESECUU\n* Yi\n* ESCANU\n* AMOROM\n* GBIUT"
# ]

# [text: "1. Reolink: E1 Zoom PTZ Camera, 4MP WiFi Indoor Camera\n2. litokam: Indoor Camera - White, 2K 3K & 5MP 2560x1920\n3. OFYOO: 4MP WiFi Indoor Camera, Pan & Tilt, Auto Tracking, Person/Pet Detection, Night Vision\n4. Smartklik: Smartklik Indoor security cameras for home, 4MP (2560x1440)\n5. YI Technology: YI 2K Home PRO Camera, 4MP (2560x1440)\n6. eufy Security: eufy Security Solo IndoorCam S350, 2K (2560x1440)\n7. Sricam: Sricam SP20 2.4G/5G WiFi PTZ Security IP Camera, 3MP (2304x1296)\n8. WNUR: WNUR 3MP Indoor PTZ WiFi Home Security Camera, 3MP (2304x1296)\n9. JOOAN: JOOAN WiFi Security Camera 4K (3840x2160), 360 degree view\n10. Kadymay: Kadymay light bulb security camera, 4K (3840x2160)\n11. VIKYLIN: 8MP Resolution 3840x2160 IP camera, 8MP (3840x2160)\n12. Swann: Swann Outdoor Security Camera 4K (3840x2160) with Siren & Spotlight\n13. GW Security: GW Security 4K (3840x2160) AI Security Camera System\n14. pelsee: pelsee P12 Pro 4K (3840x2160) Mirror Dash Cam\n15. HOOISE: HOOISE Security Cameras Outdoor Solar, 100% 4K (3840x2160)\n16. XM: XM-V2 1080P (1920x1080), XM-R2 1080P (1920x1080)\n17. Vimtag: Vimtag Pet/Dog Camera Indoor Security Camera, 4MP (2560x1440)\n18. Cloarks: Cloarks Pan/Tilt WiFi Indoor Baby/Pet Security Camera, 2K (2560x1440)\n19. Menggood: Menggood 2K HD Solar Security Camera, 3MP (2304x1296)\n20. ZOSI: ZOSI 2K PT Camera System, 3MP (2304x1296)"
# ]

output_text = {'text': "* Arlo\n* Blink\n* EZVIZ\n* Gatijan\n* HowKow\n* JAIOT\n* Kami\n* Kasa\n* LaView\n* Litokam\n* Noorio\n* Owltron\n* PANOOB\n* Reolink\n* Tapo\n* TP-Link\n* Vision Well\n* WESECUU\n* Yi\n* ESCANU\n* AMOROM\n* GBIUT"}

text = output_text['text']

app_names = text.strip().split("\n")

for app in app_names:
    print(app[2:])
# Out:
# Arlo
# Blink
# EZVIZ
# Gatijan
# HowKow
# JAIOT
# Kami
# Kasa
# LaView
# Litokam
# Noorio
# Owltron
# PANOOB
# Reolink
# Tapo
# TP-Link
# Vision Well
# WESECUU
# Yi
# ESCANU
# AMOROM
# GBIUT
